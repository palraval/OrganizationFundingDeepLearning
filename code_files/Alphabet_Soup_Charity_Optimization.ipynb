# %%
# Imports dependencies

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint

#  Imports and reads the charity_data.csv

import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drops the non-beneficial ID columns, 'EIN' and 'NAME'.

application_df = application_df.drop(columns = ['EIN'])

application_df.head()
# Out:
#                                        NAME APPLICATION_TYPE  \
# 0              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# ...

# %%
# Looks at APPLICATION_TYPE value counts to identify and replaces with "Other"

application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Creates a list of application types to be replaced

application_types_to_replace = ['T9','T13','T12','T2','T25','T14','T29','T15','T17']

# Replaces in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Checks to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Looks at CLASSIFICATION value counts to identify and replace with "Other"

application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# Creates list of classifications to be replaced based on cutoff point

class_count = application_df['CLASSIFICATION'].value_counts()

classifications_to_replace = class_count[class_count < 1883].index

# Replaces in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Checks to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Creates list of classifications to be replaced based on cutoff point

name_count = application_df['NAME'].value_counts()

names_to_replace = name_count[name_count <= 6].index

# Replaces in dataframe
for name in names_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(name, "Other")


#Checks to make sure replacement was successful

application_df['NAME'].value_counts()
# Out:
# NAME
# Other                                          20277
# PARENT BOOSTER USA INC                          1260
# TOPS CLUB INC                                    765
# UNITED STATES BOWLING CONGRESS INC               700
# WASHINGTON STATE UNIVERSITY                      492
#                                                ...
# RCI INC                                            7
# MYTEAM TRIUMPH INC                                 7
# NATIONAL ASSOCIATION OF CORPORATE DIRECTORS        7
# CHRISTIAN MEDICAL & DENTAL SOCIETY                 7
# NATIONAL KAPPA KAPPA IOTA INC                      7
# Name: count, Length: 316, dtype: int64

# %%
# Converts categorical data to numeric with `pd.get_dummies`

categories = pd.get_dummies(application_df)

categories.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  NAME_AACE INTERNATIONAL  \
# 0       1     5000              1                    False
# 1       1   108590              1                    False
# 2       1     5000              0                    False
# 3       1     6692              1                    False
# 4       1   142590              1                    False
#
#    NAME_ACE MENTOR PROGRAM OF AMERICA INC  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    NAME_AFRICAN-AMERICAN POSTAL LEAGUE UNITED FOR SUCCESS A-PLUS  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
# ...

# %%
# Splits our preprocessed data into our features and target arrays

features_array = categories.drop(columns = ['IS_SUCCESSFUL'])

target_array = categories['IS_SUCCESSFUL']

# Splits the preprocessed data into a training and testing dataset

X_train, X_test, y_train, y_test = train_test_split(features_array, target_array, random_state = 24)

# %%
# Creates a StandardScaler instance

scaler = StandardScaler()

# Fits the StandardScaler

X_scaler = scaler.fit(X_train)

# Scales the data

X_train_scaled = X_scaler.transform(X_train)

X_test_scaled = X_scaler.transform(X_test)

# %%
# Defines the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

input_features = len(X_train_scaled[0])

hidden_nodes_layer_1 = 100

hidden_nodes_layer_2 = 80

hidden_nodes_layer_3 = 60


nn = tf.keras.models.Sequential()

# First hidden layer

nn.add(tf.keras.layers.Dense(units = hidden_nodes_layer_1, input_dim = input_features, activation = 'relu'))

# Second hidden layer

nn.add(tf.keras.layers.Dense(units = hidden_nodes_layer_2, activation = 'sigmoid'))

# Third hidden layer

nn.add(tf.keras.layers.Dense(units = hidden_nodes_layer_3, activation = 'sigmoid'))


# Output layer

nn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 100)               36000
#
#  dense_1 (Dense)             (None, 80)                8080
#
#  dense_2 (Dense)             (None, 60)                4860
#
#  dense_3 (Dense)             (None, 1)                 61
#
# ...
# Total params: 49001 (191.41 KB)
# Trainable params: 49001 (191.41 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compiles the model

nn.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
# Trains the model

fitted_model = nn.fit(X_train_scaled, y_train, epochs = 125)
# Out:
# Epoch 1/125
# 804/804 [==============================] - 6s 3ms/step - loss: 0.4782 - accuracy: 0.7714
# Epoch 2/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4409 - accuracy: 0.7885
# Epoch 3/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4343 - accuracy: 0.7913
# Epoch 4/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4322 - accuracy: 0.7926
# Epoch 5/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4301 - accuracy: 0.7918
# Epoch 6/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4284 - accuracy: 0.7938
# Epoch 7/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4277 - accuracy: 0.7947
# Epoch 8/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4261 - accuracy: 0.7948
# Epoch 9/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4255 - accuracy: 0.7949
# Epoch 10/125
# ...

# %%
# Evaluates the model using the test data

model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.4670 - accuracy: 0.7910 - 506ms/epoch - 2ms/step
# Loss: 0.46699240803718567, Accuracy: 0.791020393371582

# %%
# Exports model to HDF5 file

nn.save('Alphabet_Soup_Charity_Optimization.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
